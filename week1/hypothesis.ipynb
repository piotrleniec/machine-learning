# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_sample_data(theta0, theta1):
    x = np.random.uniform(0, 10, 50)
    y = theta0 + theta1 * x + np.random.randn(50)
    
    return x, y

# %%
theta0, theta1 = np.random.uniform(-1, 1, 2)
x, y = generate_sample_data(theta0, theta1)

plt.plot(x, y, 'o')
plt.show()

# %%
def create_hypothesis(theta0, theta1):
    return lambda x: theta0 + theta1 * x

# %%
h = create_hypothesis(theta0, theta1)

plt.scatter(x, y)
plt.plot(x, h(x), color='red')
plt.show()
